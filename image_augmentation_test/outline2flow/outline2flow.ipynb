# %%
import os
import re
from openai import OpenAI

# 初始化 openai 客户端
client = OpenAI(
    api_key='sk-b7a82560100f44adb46b0bbb4970bc1e',
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)

def read_paragraphs(file_path):
    """读取txt文件，按 --- page_n.png --- 标志分段"""
    with open(file_path, 'r', encoding='utf-8') as f:
        content = f.read()

    # 使用正则按指定格式提取每一段
    pattern = r'--- page_(\d+)\.png ---\s*(.*?)\s*(?=(--- page_\d+\.png ---)|\Z)'  # \Z 表示文本结束
    matches = re.findall(pattern, content, flags=re.DOTALL)

    paragraphs = []
    for number, text, _ in matches:
        paragraphs.append((int(number), text.strip()))
    
    return paragraphs

def save_mmd(content, output_folder, page_number):
    """保存生成的 mermaid 内容到 .mmd 文件"""
    os.makedirs(output_folder, exist_ok=True)
    file_path = os.path.join(output_folder, f"page_{page_number}.mmd")
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(content)

def process_paragraphs(input_txt, output_folder):
    paragraphs = read_paragraphs(input_txt)
    total = len(paragraphs)
    if total == 0:
        print("没有找到任何段落。")
        return

    for idx, (page_number, para) in enumerate(paragraphs, start=1):
        print(f"[{idx}/{total}] 正在处理 page_{page_number} ...")
        try:
            completion = client.chat.completions.create(
                model="qwen-max-latest",
                messages=[
                    {'role': 'system', 'content': 'You are a helpful assistant.'},
                    {'role': 'user', 'content': f"""
我将给你一份使用换行和缩进表示逻辑关系的流程图，请你把它准确地替换为mermaid格式的代码，注意，开始和结束结点要用椭圆形表示，写代码时不要在代码后更改图形，而是直接在代码中表示椭圆形。最重要的是，除了mermaid代码以外，绝对不要附加任何其他内容！我只要代码本身，也不要添加代码开始或结束的标志！请给我“flowchart TD”开头的代码。
内容如下：
{para}
"""}
                ],
            )

            mmd_content = completion.choices[0].message.content
            save_mmd(mmd_content, output_folder, page_number)
            print(f"✅ page_{page_number} 处理成功，已保存为 page_{page_number}.mmd")
        except Exception as e:
            print(f"❌ page_{page_number} 处理失败，错误信息：{e}")

    print("\n🎉 全部段落处理完成！")

# 调用函数
process_paragraphs("./results_modified.txt", "./mmd_outputs")
# Out:
# [1/73] 正在处理 page_1 ...
# ✅ page_1 处理成功，已保存为 page_1.mmd
# [2/73] 正在处理 page_2 ...
# ✅ page_2 处理成功，已保存为 page_2.mmd
# [3/73] 正在处理 page_3 ...
# ✅ page_3 处理成功，已保存为 page_3.mmd
# [4/73] 正在处理 page_4 ...
# ✅ page_4 处理成功，已保存为 page_4.mmd
# [5/73] 正在处理 page_5 ...
# ✅ page_5 处理成功，已保存为 page_5.mmd
# [6/73] 正在处理 page_6 ...
# ✅ page_6 处理成功，已保存为 page_6.mmd
# [7/73] 正在处理 page_7 ...
# ✅ page_7 处理成功，已保存为 page_7.mmd
# [8/73] 正在处理 page_8 ...
# ✅ page_8 处理成功，已保存为 page_8.mmd
# [9/73] 正在处理 page_9 ...
# ✅ page_9 处理成功，已保存为 page_9.mmd
# [10/73] 正在处理 page_10 ...
# ✅ page_10 处理成功，已保存为 page_10.mmd
# [11/73] 正在处理 page_11 ...
# ✅ page_11 处理成功，已保存为 page_11.mmd
# [12/73] 正在处理 page_12 ...
# ✅ page_12 处理成功，已保存为 page_12.mmd
# [13/73] 正在处理 page_13 ...
# ✅ page_13 处理成功，已保存为 page_13.mmd
# [14/73] 正在处理 page_14 ...
# ✅ page_14 处理成功，已保存为 page_14.mmd
# [15/73] 正在处理 page_15 ...
# ✅ page_15 处理成功，已保存为 page_15.mmd
# [16/73] 正在处理 page_16 ...
# ✅ page_16 处理成功，已保存为 page_16.mmd
# [17/73] 正在处理 page_17 ...
# ✅ page_17 处理成功，已保存为 page_17.mmd
# [18/73] 正在处理 page_18 ...
# ✅ page_18 处理成功，已保存为 page_18.mmd
# [19/73] 正在处理 page_19 ...
# ✅ page_19 处理成功，已保存为 page_19.mmd
# [20/73] 正在处理 page_20 ...
# ✅ page_20 处理成功，已保存为 page_20.mmd
# [21/73] 正在处理 page_21 ...
# ✅ page_21 处理成功，已保存为 page_21.mmd
# [22/73] 正在处理 page_22 ...
# ✅ page_22 处理成功，已保存为 page_22.mmd
# [23/73] 正在处理 page_23 ...
# ✅ page_23 处理成功，已保存为 page_23.mmd
# [24/73] 正在处理 page_24 ...
# ✅ page_24 处理成功，已保存为 page_24.mmd
# [25/73] 正在处理 page_25 ...
# ✅ page_25 处理成功，已保存为 page_25.mmd
# [26/73] 正在处理 page_26 ...
# ✅ page_26 处理成功，已保存为 page_26.mmd
# [27/73] 正在处理 page_27 ...
# ✅ page_27 处理成功，已保存为 page_27.mmd
# [28/73] 正在处理 page_28 ...
# ✅ page_28 处理成功，已保存为 page_28.mmd
# [29/73] 正在处理 page_29 ...
# ✅ page_29 处理成功，已保存为 page_29.mmd
# [30/73] 正在处理 page_30 ...
# ✅ page_30 处理成功，已保存为 page_30.mmd
# [31/73] 正在处理 page_31 ...
# ✅ page_31 处理成功，已保存为 page_31.mmd
# [32/73] 正在处理 page_32 ...
# ✅ page_32 处理成功，已保存为 page_32.mmd
# [33/73] 正在处理 page_33 ...
# ✅ page_33 处理成功，已保存为 page_33.mmd
# [34/73] 正在处理 page_34 ...
# ✅ page_34 处理成功，已保存为 page_34.mmd
# [35/73] 正在处理 page_35 ...
# ✅ page_35 处理成功，已保存为 page_35.mmd
# [36/73] 正在处理 page_36 ...
# ✅ page_36 处理成功，已保存为 page_36.mmd
# [37/73] 正在处理 page_37 ...
# ✅ page_37 处理成功，已保存为 page_37.mmd
# [38/73] 正在处理 page_38 ...
# ✅ page_38 处理成功，已保存为 page_38.mmd
# [39/73] 正在处理 page_39 ...
# ✅ page_39 处理成功，已保存为 page_39.mmd
# [40/73] 正在处理 page_40 ...
# ✅ page_40 处理成功，已保存为 page_40.mmd
# [41/73] 正在处理 page_41 ...
# ✅ page_41 处理成功，已保存为 page_41.mmd
# [42/73] 正在处理 page_42 ...
# ✅ page_42 处理成功，已保存为 page_42.mmd
# [43/73] 正在处理 page_43 ...
# ✅ page_43 处理成功，已保存为 page_43.mmd
# [44/73] 正在处理 page_44 ...
# ✅ page_44 处理成功，已保存为 page_44.mmd
# [45/73] 正在处理 page_45 ...
# ✅ page_45 处理成功，已保存为 page_45.mmd
# [46/73] 正在处理 page_46 ...
# ✅ page_46 处理成功，已保存为 page_46.mmd
# [47/73] 正在处理 page_47 ...
# ✅ page_47 处理成功，已保存为 page_47.mmd
# [48/73] 正在处理 page_48 ...
# ✅ page_48 处理成功，已保存为 page_48.mmd
# [49/73] 正在处理 page_49 ...
# ✅ page_49 处理成功，已保存为 page_49.mmd
# [50/73] 正在处理 page_50 ...
# ✅ page_50 处理成功，已保存为 page_50.mmd
# [51/73] 正在处理 page_51 ...
# ✅ page_51 处理成功，已保存为 page_51.mmd
# [52/73] 正在处理 page_52 ...
# ✅ page_52 处理成功，已保存为 page_52.mmd
# [53/73] 正在处理 page_53 ...
# ✅ page_53 处理成功，已保存为 page_53.mmd
# [54/73] 正在处理 page_54 ...
# ✅ page_54 处理成功，已保存为 page_54.mmd
# [55/73] 正在处理 page_55 ...
# ✅ page_55 处理成功，已保存为 page_55.mmd
# [56/73] 正在处理 page_56 ...
# ✅ page_56 处理成功，已保存为 page_56.mmd
# [57/73] 正在处理 page_57 ...
# ✅ page_57 处理成功，已保存为 page_57.mmd
# [58/73] 正在处理 page_58 ...
# ✅ page_58 处理成功，已保存为 page_58.mmd
# [59/73] 正在处理 page_59 ...
# ✅ page_59 处理成功，已保存为 page_59.mmd
# [60/73] 正在处理 page_60 ...
# ✅ page_60 处理成功，已保存为 page_60.mmd
# [61/73] 正在处理 page_61 ...
# ✅ page_61 处理成功，已保存为 page_61.mmd
# [62/73] 正在处理 page_62 ...
# ✅ page_62 处理成功，已保存为 page_62.mmd
# [63/73] 正在处理 page_63 ...
# ✅ page_63 处理成功，已保存为 page_63.mmd
# [64/73] 正在处理 page_64 ...
# ✅ page_64 处理成功，已保存为 page_64.mmd
# [65/73] 正在处理 page_65 ...
# ✅ page_65 处理成功，已保存为 page_65.mmd
# [66/73] 正在处理 page_66 ...
# ✅ page_66 处理成功，已保存为 page_66.mmd
# [67/73] 正在处理 page_67 ...
# ✅ page_67 处理成功，已保存为 page_67.mmd
# [68/73] 正在处理 page_68 ...
# ✅ page_68 处理成功，已保存为 page_68.mmd
# [69/73] 正在处理 page_69 ...
# ✅ page_69 处理成功，已保存为 page_69.mmd
# [70/73] 正在处理 page_70 ...
# ✅ page_70 处理成功，已保存为 page_70.mmd
# [71/73] 正在处理 page_71 ...
# ✅ page_71 处理成功，已保存为 page_71.mmd
# [72/73] 正在处理 page_72 ...
# ✅ page_72 处理成功，已保存为 page_72.mmd
# [73/73] 正在处理 page_73 ...
# ✅ page_73 处理成功，已保存为 page_73.mmd
#
# 🎉 全部段落处理完成！

# %%
# !./convert_mmd_to_png.sh /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs
# Out:
# 找不到 mmdc 命令，尝试添加 nvm 的路径到 PATH...
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_10.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_10.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_11.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_11.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_12.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_12.png
# Generating single mermaid chart
# [@zenuml/core] Store is a function and is not initiated in 1 second.
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_13.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_13.png
# Generating single mermaid chart
# [@zenuml/core] Store is a function and is not initiated in 1 second.
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_14.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_14.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_15.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_15.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_16.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_16.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_17.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_17.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_18.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_18.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_19.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_19.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_1.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_1.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_20.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_20.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_21.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_21.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_22.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_22.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_23.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_23.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_24.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_24.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_25.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_25.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_26.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_26.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_27.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_27.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_28.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_28.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_29.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_29.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_2.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_2.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_30.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_30.png
# Generating single mermaid chart
# [@zenuml/core] Store is a function and is not initiated in 1 second.
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_31.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_31.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_32.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_32.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_33.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_33.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_34.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_34.png
# Generating single mermaid chart
# [@zenuml/core] Store is a function and is not initiated in 1 second.
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_35.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_35.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_36.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_36.png
# Generating single mermaid chart
# [@zenuml/core] Store is a function and is not initiated in 1 second.
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_37.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_37.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_38.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_38.png
# Generating single mermaid chart
# [@zenuml/core] Store is a function and is not initiated in 1 second.
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_39.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_39.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_3.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_3.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_40.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_40.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_41.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_41.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_42.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_42.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_43.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_43.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_44.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_44.png
# Generating single mermaid chart
#
# Error: Lexical error on line 12. Unrecognized text.
# ... 供应商谈判 --> 购置申请表谈判小组≥3人    购置申请表谈判小组≥3人
# -----------------------^
# Parser3.parseError (/home/ymai/.nvm/versions/node/v20.19.1/lib/node_modules/@mermaid-js/mermaid-cli/node_modules/mermaid/dist/mermaid.js:56102:28)
#     at #evaluate (file:///home/ymai/.nvm/versions/node/v20.19.1/lib/node_modules/@mermaid-js/mermaid-cli/node_modules/puppeteer-core/lib/esm/puppeteer/cdp/ExecutionContext.js:388:19)
#     at async ExecutionContext.evaluate (file:///home/ymai/.nvm/versions/node/v20.19.1/lib/node_modules/@mermaid-js/mermaid-cli/node_modules/puppeteer-core/lib/esm/puppeteer/cdp/ExecutionContext.js:275:16)
#     at async IsolatedWorld.evaluate (file:///home/ymai/.nvm/versions/node/v20.19.1/lib/node_modules/@mermaid-js/mermaid-cli/node_modules/puppeteer-core/lib/esm/puppeteer/cdp/IsolatedWorld.js:97:16)
#     at async CdpJSHandle.evaluate (file:///home/ymai/.nvm/versions/node/v20.19.1/lib/node_modules/@mermaid-js/mermaid-cli/node_modules/puppeteer-core/lib/esm/puppeteer/api/JSHandle.js:146:20)
#     at async CdpElementHandle.evaluate (file:///home/ymai/.nvm/versions/node/v20.19.1/lib/node_modules/@mermaid-js/mermaid-cli/node_modules/puppeteer-core/lib/esm/puppeteer/api/ElementHandle.js:340:20)
#     at async CdpElementHandle.$eval (file:///home/ymai/.nvm/versions/node/v20.19.1/lib/node_modules/@mermaid-js/mermaid-cli/node_modules/puppeteer-core/lib/esm/puppeteer/api/ElementHandle.js:494:24)
#     at async CdpFrame.$eval (file:///home/ymai/.nvm/versions/node/v20.19.1/lib/node_modules/@mermaid-js/mermaid-cli/node_modules/puppeteer-core/lib/esm/puppeteer/api/Frame.js:450:20)
#     at async CdpPage.$eval (file:///home/ymai/.nvm/versions/node/v20.19.1/lib/node_modules/@mermaid-js/mermaid-cli/node_modules/puppeteer-core/lib/esm/puppeteer/api/Page.js:450:20)
#     at async renderMermaid (file:///home/ymai/.nvm/versions/node/v20.19.1/lib/node_modules/@mermaid-js/mermaid-cli/src/index.js:252:22)
#     at fromText (/home/ymai/.nvm/versions/node/v20.19.1/lib/node_modules/@mermaid-js/mermaid-cli/node_modules/mermaid/dist/mermaid.js:151117:21)
#
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_45.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_45.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_46.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_46.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_47.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_47.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_48.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_48.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_49.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_49.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_4.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_4.png
# Generating single mermaid chart
# [@zenuml/core] Store is a function and is not initiated in 1 second.
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_50.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_50.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_51.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_51.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_52.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_52.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_53.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_53.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_54.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_54.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_55.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_55.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_56.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_56.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_57.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_57.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_58.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_58.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_59.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_59.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_5.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_5.png
# Generating single mermaid chart
# [@zenuml/core] Store is a function and is not initiated in 1 second.
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_60.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_60.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_61.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_61.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_62.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_62.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_63.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_63.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_64.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_64.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_65.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_65.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_66.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_66.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_67.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_67.png
# Generating single mermaid chart
# [@zenuml/core] Store is a function and is not initiated in 1 second.
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_68.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_68.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_69.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_69.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_6.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_6.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_70.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_70.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_71.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_71.png
# Generating single mermaid chart
# [@zenuml/core] Store is a function and is not initiated in 1 second.
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_72.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_72.png
# Generating single mermaid chart
# [@zenuml/core] Store is a function and is not initiated in 1 second.
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_73.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_73.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_7.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_7.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_8.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_8.png
# Generating single mermaid chart
# 正在处理: /home/ymai/work1/image_augmentation_test/outline2flow/mmd_outputs/page_9.mmd -> /home/ymai/work1/image_augmentation_test/outline2flow/flow_outputs/page_9.png
# Generating single mermaid chart
# 全部完成！
