# %%
from openai import OpenAI
 
client = OpenAI(
    api_key = "sk-G5mnzUvoMrzk5ql2F9F74a3a3a0d42059d5b5094319a443c",  # 这里填写  OneAPI生成的令牌  第7步获取的令牌
 
    # 中转地址    填写自己 OneAPI 地址     如http://127.0.0.1:3000是OneAPI网页地址   完整部分需要再加上/v1      需要根据实际地址进行填写
    base_url = "http://10.15.8.32:3000/v1"
)
chat_completion = client.chat.completions.create(
    model="deepseek-r1", #       填写我们 OneAPI  搭建的模型调用渠道
    messages=[
        {
            "role": "user",
            "content": "请用中文讲个笑话",
        }
    ]
)

print(chat_completion.choices[0].message.content)
# Out:
# 好的，用户让我用中文讲个笑话。首先，我需要确定用户的需求是什么。他们可能是在寻找轻松的笑话，用来缓解压力或者娱乐一下。接下来，我得考虑笑话的受众，是成人还是小孩？如果是成人，笑话可以稍微复杂一些，或者带点双关语；如果是小孩，就需要更简单、无伤大雅的内容。
#
# 然后，我要回忆一些常见的中文笑话结构。比如谐音梗、反转结局、日常生活中的搞笑场景等等。中文笑话常用谐音，因为汉字有很多同音字，容易制造笑点。例如“为什么自行车会倒？因为它站累了。”这里“站累了”和“站不住”有谐音的效果。
#
# 不过，用户可能已经听过很多常见的笑话，所以我需要想一个不太常见但又容易理解的。另外，笑话的长度也很重要，太长的可能效果不好，短小精悍的更容易让人发笑。
#
# 再考虑文化差异，用户可能来自不同的地区，但使用中文的话，应该以普通话为主，避免方言笑话，除非确定用户能理解。比如台湾和大陆有些用词不同，要选通用的词汇。
#
# 还有，笑话的主题要合适，不能涉及敏感话题，避免冒犯到用户。最好选择日常生活相关的内容，比如家庭、工作、学校等，这样更容易引起共鸣。
#
# 现在，我想到一个关于打电话的笑话，可能符合要求。比如：“小明打电话给妈妈：‘妈妈，我刚刚看到一只老鼠在吃我的作业！’妈妈回答：‘别担心，我明天再给你买只猫。’小明说：‘可是猫会把我的作业抓烂啊！’” 这个笑话利用了孩子常见的借口，妈妈的回答却出乎意料，最后还有反转，可能让人会心一笑。
#
# 不过，可能还有更好的选择。比如，另一个经典结构是问答式笑话。例如：“为什么数学书总是很悲伤？因为它有太多的问题。” 这里的“问题”双关，既指数学题目，又指烦恼，这样的笑话简单易懂，又带有双关，效果不错。
#
# 或者用动物做主角，比如：“为什么螃蟹横着走？因为它有钳（钱）任性！” 这里用“钳”和“钱”谐音，符合中文的谐音梗，也比较有趣。
#
# 再想想有没有更贴近日常生活的例子。比如：“今天去面试，面试官问我：‘你有什么缺点？’我说：‘我方向感不太好。’面试官说：‘比如？’我回答：‘比如，我现在找不到回家的路，你能送我一下吗？’” 这个笑话利用面试中的对话制造幽默，结局出人意料，可能效果不错。
#
# ...
